# %%
pwd
# Out:
# u'C:\\Users\\fcont\\Documents\\Python Master\\Corey'

# %%
#based on https://www.youtube.com/watch?v=Q06Y3DUSwz4

# %%
import pandas as pd
statesLFP = pd.read_excel('C:\\Users\\fcont\\Documents\\Python Master\\Corey\\State-LFPRates.xlsx',0)
statesLFP.head(5)
# Out:
#    FIPS Code State and area  Year  Month  Civilian non-Inst. population  \
# 0          1        Alabama  1976      1                        2605000
# 1          2         Alaska  1976      1                         232000
# 2          4        Arizona  1976      1                        1621000
# 3          5       Arkansas  1976      1                        1536000
# 4          6     California  1976      1                       15621000
#
#    Civilian labor force  CL-Pct of Pop.  Employment  E-Pct of Pop.  \
# 0               1492409            57.3     1392154           53.4
# 1                159154            68.6      147809           63.7
# 2                972413            60.0      872738           53.8
# 3                882835            57.5      817756           53.2
# 4               9781720            62.6     8892663           56.9
#
#    Unemployed  U-Rate
# 0      100255     6.7
# 1       11345     7.1
# 2       99675    10.3
# 3       65079     7.4
# ...

# %%
#statesLFP[statesLFP['State and area']=='Massachusetts'].describe()
statesLFP[statesLFP['State and area']=='Massachusetts']
# Out:
#        FIPS Code State and area  Year  Month  Civilian non-Inst. population  \
# 22            25  Massachusetts  1976      1                        4194000
# 75            25  Massachusetts  1976      2                        4198000
# 128           25  Massachusetts  1976      3                        4201000
# 181           25  Massachusetts  1976      4                        4204000
# 234           25  Massachusetts  1976      5                        4207000
# 287           25  Massachusetts  1976      6                        4210000
# 340           25  Massachusetts  1976      7                        4213000
# 393           25  Massachusetts  1976      8                        4217000
# 446           25  Massachusetts  1976      9                        4220000
# 499           25  Massachusetts  1976     10                        4224000
# 552           25  Massachusetts  1976     11                        4227000
# ...

# %%
#football = pd.read_excel('football.xlsx', 'Sheet1')
#football

# %%
import pandas as pd
df= pd.read_excel('C:\\Users\\fcont\\Documents\\Python Master\\Corey\\State-LFPRates.xlsx',0)
df.head(5)
#for testing only use cell 2 code
#df.to_html('newfc.html')
#df  = pd.DataFrame('State-LFPRates.xlsx', columns=['State and area'])
'''df ['U-Rate'].mean()
df ['State and area'].count()
df ['CL-Pct of Pop.'].count()
#df[['State and area', 'U-Rate']][df.'U-Rate'==df['U-Rate'].max()]
df[['State and area', 'U-Rate']]
#df[df.['U-Rate']==10.6]
df[df['State and area']==[df['Massachusetts']]
df[df.State=="Massachusetts"]'''
df.columns
df
# Out:
#        FIPS Code        State and area  Year  Month  \
# 0              1               Alabama  1976      1
# 1              2                Alaska  1976      1
# 2              4               Arizona  1976      1
# 3              5              Arkansas  1976      1
# 4              6            California  1976      1
# 5             37    Los Angeles County  1976      1
# 6              8              Colorado  1976      1
# 7              9           Connecticut  1976      1
# 8             10              Delaware  1976      1
# 9             11  District of Columbia  1976      1
# 10            12               Florida  1976      1
# 11            13               Georgia  1976      1
# 12            15                Hawaii  1976      1
# 13            16                 Idaho  1976      1
# 14            17              Illinois  1976      1
# 15            18               Indiana  1976      1
# 16            19                  Iowa  1976      1
# ...

# %%
type ('State and area')

# %%
df.columns
# Out:
# Index([                    u'FIPS Code',                u'State and area',
#                                 u'Year',                         u'Month',
#        u'Civilian non-Inst. population',          u'Civilian labor force',
#                       u'CL-Pct of Pop.',                    u'Employment',
#                        u'E-Pct of Pop.',                    u'Unemployed',
#                               u'U-Rate',                     u'FIPS code'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26818 entries, 0 to 26817
# Data columns (total 12 columns):
# FIPS Code                        26818 non-null int64
# State and area                   26818 non-null object
# Year                             26818 non-null int64
# Month                            26818 non-null int64
# Civilian non-Inst. population    26818 non-null int64
# Civilian labor force             26818 non-null int64
# CL-Pct of Pop.                   26818 non-null float64
# Employment                       26818 non-null int64
# E-Pct of Pop.                    26818 non-null float64
# Unemployed                       26818 non-null int64
# U-Rate                           26818 non-null float64
# FIPS code                        26818 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 2.5+ MB

# %%
address = "State-LFPRates.xlsx"
krate = pd.read_excel(address)
krate.columns = ['FIPS Code', 'State and area', 'Year', 'Month', 'Civilian non-Inst. population', 'CL-Pct of Pop.','Civilian labor force','CL-Pct of Pop.','Employment', 'E-Pct of Pop.' 'Unemployed', 'U-Rate']

krate.head()

krate_group = krate.groupby(krate['State and area'])
df[df['State and area'].str.match('Massachusetts')]
df[df['State and area'].str.match('New Jersey')]
# Out:
#        FIPS Code State and area  Year  Month  Civilian non-Inst. population  \
# 31            34     New Jersey  1976      1                        5358000
# 84            34     New Jersey  1976      2                        5363000
# 137           34     New Jersey  1976      3                        5367000
# 190           34     New Jersey  1976      4                        5372000
# 243           34     New Jersey  1976      5                        5376000
# 296           34     New Jersey  1976      6                        5381000
# 349           34     New Jersey  1976      7                        5385000
# 402           34     New Jersey  1976      8                        5389000
# 455           34     New Jersey  1976      9                        5394000
# 508           34     New Jersey  1976     10                        5398000
# 561           34     New Jersey  1976     11                        5403000
# ...

# %%
g = df.groupby("Month")
g

# %%
for 'State and area' in g:
    print("State and area:",'State and area')
    print("\n")

# %%
df ['State and area'] = 'Massachusetts'
df
# Out:
#        FIPS Code State and area  Year  Month  Civilian non-Inst. population  \
# 0             25  Massachusetts  1976      1                        2605000
# 1             25  Massachusetts  1976      1                         232000
# 2             25  Massachusetts  1976      1                        1621000
# 3             25  Massachusetts  1976      1                        1536000
# 4             25  Massachusetts  1976      1                       15621000
# 5             25  Massachusetts  1976      1                        5273000
# 6             25  Massachusetts  1976      1                        1832000
# 7             25  Massachusetts  1976      1                        2248000
# 8             25  Massachusetts  1976      1                         417000
# 9             25  Massachusetts  1976      1                         520000
# 10            25  Massachusetts  1976      1                        6421000
# ...

# %%
ticks = df.loc[:, ['FIPS Code', 'State and area']]
ticks.head()
# Out:
#    FIPS Code State and area
# 0         25  Massachusetts
# 1         25  Massachusetts
# 2         25  Massachusetts
# 3         25  Massachusetts
# 4         25  Massachusetts

# %%
url = 'https://raw.github.com/gjreda/best-sandwiches/master/data/best-sandwiches-geocode.tsv'

# fetch the text from the URL and read it into a DataFrame
from_url = pd.read_table(url, sep='\t')
from_url.head(3)
# Out:
#    rank           sandwich   restaurant  \
# 0     1                BLT  Old Oak Tap
# 1     2      Fried Bologna    Au Cheval
# 2     3  Woodland Mushroom         Xoco
#
#                                          description   price  \
# 0  The B is applewood smoked&mdash;nice and snapp...     $10
# 1  Thought your bologna-eating days had retired w...      $9
# 2  Leave it to Rick Bayless and crew to come up w...  $9.50.
#
#                 address     city         phone              website  \
# 0  2109 W. Chicago Ave.  Chicago  773-772-0406     theoldoaktap.com
# 1   800 W. Randolph St.  Chicago  312-929-4580  aucheval.tumblr.com
# 2      445 N. Clark St.  Chicago  312-334-3688      rickbayless.com
#
#                     full_address  \
# 0  2109 W. Chicago Ave., Chicago
# 1   800 W. Randolph St., Chicago
# 2      445 N. Clark St., Chicago
#
#                                   formatted_address        lat        lng
# ...

# %%
print('Massachusetts' in 'State and area')
# Out:
# False

# %%
# read from Excel
states = pd.read_excel('State-LFPRates.xlsx')
states
# Out:
#        FIPS Code        State and area  Year  Month  \
# 0              1               Alabama  1976      1
# 1              2                Alaska  1976      1
# 2              4               Arizona  1976      1
# 3              5              Arkansas  1976      1
# 4              6            California  1976      1
# 5             37    Los Angeles County  1976      1
# 6              8              Colorado  1976      1
# 7              9           Connecticut  1976      1
# 8             10              Delaware  1976      1
# 9             11  District of Columbia  1976      1
# 10            12               Florida  1976      1
# 11            13               Georgia  1976      1
# 12            15                Hawaii  1976      1
# 13            16                 Idaho  1976      1
# 14            17              Illinois  1976      1
# 15            18               Indiana  1976      1
# 16            19                  Iowa  1976      1
# ...

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26818 entries, 0 to 26817
# Data columns (total 11 columns):
# FIPS Code                        26818 non-null int64
# State and area                   26818 non-null object
# Year                             26818 non-null int64
# Month                            26818 non-null int64
# Civilian non-Inst. population    26818 non-null int64
# Civilian labor force             26818 non-null int64
# CL-Pct of Pop.                   26818 non-null float64
# Employment                       26818 non-null int64
# E-Pct of Pop.                    26818 non-null float64
# Unemployed                       26818 non-null int64
# U-Rate                           26818 non-null float64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 2.3+ MB

# %%
states.dtypes
# Out:
# FIPS Code                          int64
# State and area                    object
# Year                               int64
# Month                              int64
# Civilian non-Inst. population      int64
# Civilian labor force               int64
# CL-Pct of Pop.                   float64
# Employment                         int64
# E-Pct of Pop.                    float64
# Unemployed                         int64
# U-Rate                           float64
# dtype: object

# %%
states.describe()
# Out:
#           FIPS Code          Year         Month  \
# count  26818.000000  26818.000000  26818.000000
# mean     990.830189   1996.584980      6.480237
# std     6935.170515     12.172155      3.459685
# min        1.000000   1976.000000      1.000000
# 25%       17.000000   1986.000000      3.000000
# 50%       30.000000   1997.000000      6.000000
# 75%       42.000000   2007.000000      9.000000
# max    51000.000000   2018.000000     12.000000
#
#        Civilian non-Inst. population  Civilian labor force  CL-Pct of Pop.  \
# count                   2.681800e+04          2.681800e+04    26818.000000
# mean                    4.123725e+06          2.676443e+06       65.813741
# std                     4.453745e+06          2.867184e+06        4.239998
# min                     2.320000e+05          1.589610e+05       50.300000
# 25%                     1.074980e+06          7.058398e+05       63.100000
# 50%                     2.868242e+06          1.842620e+06       66.200000
# ...

# %%
states.head(5)
# Out:
#    FIPS Code State and area  Year  Month  Civilian non-Inst. population  \
# 0          1        Alabama  1976      1                        2605000
# 1          2         Alaska  1976      1                         232000
# 2          4        Arizona  1976      1                        1621000
# 3          5       Arkansas  1976      1                        1536000
# 4          6     California  1976      1                       15621000
#
#    Civilian labor force  CL-Pct of Pop.  Employment  E-Pct of Pop.  \
# 0               1492409            57.3     1392154           53.4
# 1                159154            68.6      147809           63.7
# 2                972413            60.0      872738           53.8
# 3                882835            57.5      817756           53.2
# 4               9781720            62.6     8892663           56.9
#
#    Unemployed  U-Rate
# 0      100255     6.7
# 1       11345     7.1
# 2       99675    10.3
# 3       65079     7.4
# ...

# %%
states[27:42]
# Out:
#     FIPS Code  State and area  Year  Month  Civilian non-Inst. population  \
# 27         30         Montana  1976      1                         531000
# 28         31        Nebraska  1976      1                        1095000
# 29         32          Nevada  1976      1                         451000
# 30         33   New Hampshire  1976      1                         593000
# 31         34      New Jersey  1976      1                        5358000
# 32         35      New Mexico  1976      1                         792000
# 33         36        New York  1976      1                       13196000
# 34      51000   New York city  1976      1                        5694000
# 35         37  North Carolina  1976      1                        3898000
# 36         38    North Dakota  1976      1                         442000
# 37         39            Ohio  1976      1                        7701000
# 38         40        Oklahoma  1976      1                        1999000
# ...

# %%
states['State and area'].head(51)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-15-3f34a9c5c0da> in <module>()
# ----> 1 states['State and area'].head(51)
#
# NameError: name 'states' is not defined

# %%
from IPython.core.display import HTML
HTML("<iframe src=http://www.bls.gov width=800 height=350></iframe>")
# Out:
# <iframe src=http://www.bls.gov width=800 height=350></iframe>

# %%
type(states)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-16-4f670d6cdf5b> in <module>()
# ----> 1 type(states)
#
# NameError: name 'states' is not defined

# %%
states.loc[12321]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-17-42b68f0c2f33> in <module>()
# ----> 1 states.loc[12321]
#
# NameError: name 'states' is not defined

# %%
states.info()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-18-51c4485b54ef> in <module>()
# ----> 1 states.info()
#
# NameError: name 'states' is not defined

# %%
states.dtypes
# Out:
# FIPS Code                          int64
# State and area                    object
# Year                               int64
# Month                              int64
# Civilian non-Inst. population      int64
# Civilian labor force               int64
# CL-Pct of Pop.                   float64
# Employment                         int64
# E-Pct of Pop.                    float64
# Unemployed                         int64
# U-Rate                           float64
# dtype: object

# %%
#import webbrowser
#webbrowser.open ('http://www.bls.gov/')
# Out:
# True

# %%
import types
def imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            yield val.__name__
list(imports())
# Out:
# ['IPython.core.shadowns',
#  'requests',
#  'sys',
#  '__builtin__',
#  '__builtin__',
#  'pandas',
#  'webbrowser',
#  'types']
